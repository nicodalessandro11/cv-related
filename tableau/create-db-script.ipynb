# %%
# Adjusting the dataframe to match the user's specifications
# Creating individual columns for each category based on the user's instructions
data_adjusted = {
    "Section": [
        # Personal Information
        "Personal Information", "Personal Information", "Personal Information", "Personal Information",
        # Who Am I
        "Who Am I", "Who Am I", "Who Am I",
        # Education
        "Education", "Education", "Education", "Education", "Education",
        # Work Experience
        "Work Experience", "Work Experience", "Work Experience", "Work Experience", "Work Experience", "Work Experience", "Work Experience", "Work Experience", "Work Experience",
        # Courses & Certifications
        "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications", "Courses & Certifications",
        # Skills
        "Soft Skills", "Soft Skills", "Soft Skills", "Soft Skills", "Soft Skills", "Soft Skills",
        # Tech Stack
        "Tech Stack", "Tech Stack", "Tech Stack", "Tech Stack", "Tech Stack", "Tech Stack"
    ],
    "Item": [
        # Personal Information
        "Name", "Email", "Phone", "LinkedIn",
        # Who Am I
        "Profile", "Key Skills", "Quote",
        # Education
        "Master's Degree", "Postgraduate", "Bachelor's Degree", "CFGS", "Technical Degree",
        # Work Experience
        "Play'n GO", "Amazon", "Amazon", "ISS Facility Services", "ISS Facility Services", "Grupo Cargo SA at Volkswagen Argentina", "Grupo Cargo SA at Volkswagen Argentina", "Ford Argentina", "Ford Argentina",
        # Courses & Certifications
        "Specialization in AI", "Web Front End Bootcamp", "Data Mining for BI", "Big Data & ML Development", "Python Programming", "Applied ML Workshop", "Web Data Extraction Summit", "Purchasing & Logistics", "CAE Advanced English", "Workaway Language Program",
        # Skills
        "Critical Thinking", "Problem Solving", "Attention to Detail", "Project Management", "Storytelling & Communication", "Adaptability & Collaboration",
        # Tech Stack
        "SQL", "Python, R, Java, etc.", "Math & Statistics", "Tableau, DataViz", "Cloud Computing", "Web Full Stack"
    ],
    "Center/Job Position": [
        # Personal Information
        "", "", "", "",
        # Who Am I
        "", "", "",
        # Education
        "Universidad Camilo José Cela", "EADA Business School", "Universitat Oberta de Catalunya", "IFP Barcelona", "Ford Argentina S.C.A",
        # Work Experience
        "Senior Product Data Analyst", "Senior Business Data Analyst", "Logistics Data Analyst & Lead Learning Coordinator", 
        "Business Solutions Data Analyst", "Logistics Data Analyst", "Quality Assurance Specialist", "Logistics Analyst", 
        "Administrative", "Student Internship",
        # Courses & Certifications
        "Valencian Graduate School of AI", "IRONHACK", "EUROFORMAC", "UOC", "Cisco Networking Academy", "DataHack", 
        "ScrapingHub", "UOC", "Cambridge", "North Carolina, USA",
        # Skills
        "", "", "", "", "", "",
        # Tech Stack
        "", "", "", "", "", ""
    ],
    "Description": [
        # Personal Information
        "Nicolas D'Alessandro", "nicodalesandro11@gmail.com", "+34 695 972 556", "linkedin.com/in/nicolasdalessandro",
        # Who Am I
        "Passionate lifelong learner and creative data enthusiast with experience in business intelligence, data science, analytics, and engineering.", 
        "Solving business challenges using data analytics, modeling, and visualization.", 
        "I love merging art, data, and technology to create impactful solutions.",
        # Education
        "Master's Degree in Business Analytics & Big Data", 
        "Postgraduate in Data Analytics", 
        "Bachelor's Degree in Techniques for Software Application Development", 
        "CFGS - Higher Education in Multiplatform App Development (DAM)", 
        "Industrial & Electromechanical Technician",
        # Work Experience
        "Game analytics and product insights. Engineering Department, Sweden, Remote", 
        "BI solutions & data analysis for operational improvements. Central Ops Department, Barcelona", 
        "Logistics data analysis and new joiners training. Risk & Flow Department, Barcelona", 
        "BI solutions for process optimization. Excellence Service Department, Barcelona", 
        "Logistics support and shipment tracking, Shipping Department at HP Spain, Barcelona", 
        "Quality monitoring and compliance using ISO standards, JIT Department, Bs. As.", 
        "Logistics analysis and Supply Chain Management. Milkrun & Kanban Department, Bs. As.", 
        " Controller & budgeting, L&D Department, Bs. As.", 
        "Customer Service Division, Bs. As.",
        # Courses & Certifications
        "Specialization in AI for ICT Professionals", 
        "Web Front End Development Bootcamp", 
        "Data Mining for Business Intelligence", 
        "Big Data & ML Development", 
        "Programming Essentials in Python", 
        "Workshop in Applied ML", 
        "Web Data Extraction Summit", 
        "Certificate of Education in Purchasing & Logistics", 
        "CAE Advanced English", 
        "Workaway Language Exchange Program",
        # Skills
        "Strong analytical skills", "Effective problem-solving", "Data storytelling & presentation", 
        "Project coordination & planning", "Adaptable to change", "Teamwork and collaboration",
        # Tech Stack
        "SQL, ETL/ELT & Database Management", "Proficient in multiple scripting languages", 
        "Mathematics & statistical modeling", "Tableau, QuickSight, other DataViz tools", 
        "Cloud Computing tools", "HTML, CSS, REACTjs, VUE.js"
    ],
    "Date (Year)": [
        # Personal Information
        "", "", "", "",
        # Who Am I
        "", "", "",
        # Education
        "Currently", "2020", "2021", "2016", "2007",
        # Work Experience
        "Currently", "2020 - 2024", "2020 - 2024", "2016 - 2020", "2016 - 2020", "2008 - 2014", "2008 - 2014", "2004 - 2007", "2004 - 2007",
        # Courses & Certifications
        "Currently", "2023", "2022", "2020", "2020", "2019", "2019", "2018", "2018", "2016",
        # Skills
        "", "", "", "", "", "",
        # Tech Stack
        "", "", "", "", "", ""
    ],
    "Proficiency (1-5 / 1-10)": [
        # Personal Information
        "", "", "", "",
        # Who Am I
        "", "", "",
        # Education
        "", "", "", "", "",
        # Work Experience
        "", "", "", "", "", "", "", "", "",
        # Courses & Certifications
        "", "", "", "", "", "", "", "", "", "",
        # Skills
        5, 5, 4, 4, 4, 4,
        # Tech Stack
        8, 7, 7, 8, 6, 7
    ]
}

# Creating the new dataframe with the additional fields
df_adjusted = pd.DataFrame(data_adjusted)

# Saving the new dataframe to a CSV file
csv_path_adjusted = "Nicolas_CV_Data.csv"
df_adjusted.to_csv(csv_path_adjusted, index=False)

# %%
df_adjusted
# Out:
#                      Section                                    Item  \
# 0       Personal Information                                    Name
# 1       Personal Information                                   Email
# 2       Personal Information                                   Phone
# 3       Personal Information                                LinkedIn
# 4                   Who Am I                                 Profile
# 5                   Who Am I                              Key Skills
# 6                   Who Am I                                   Quote
# 7                  Education                         Master's Degree
# 8                  Education                            Postgraduate
# 9                  Education                       Bachelor's Degree
# 10                 Education                                    CFGS
# 11                 Education                        Technical Degree
# 12           Work Experience                               Play'n GO
# ...
